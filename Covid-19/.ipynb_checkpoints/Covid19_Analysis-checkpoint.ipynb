# %% [markdown]
# ### Load necessary libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import scipy.stats as scs
import os

# %% [markdown]
# ### Load the data

# %%
df = pd.read_csv('covid_19_data.csv')

# %%
df.shape
# Out:
# (321, 6)

# %%
df.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %% [markdown]
# ### Check basic stats infomation of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
df.describe()
# Out:
#            Confirmed        Deaths      Recovered
# count     321.000000    321.000000     321.000000
# mean     9949.800623    709.152648    3030.277259
# std     31923.853086   3236.162817   14364.870365
# min         0.000000      0.000000       0.000000
# 25%       104.000000      2.000000       2.000000
# 50%       653.000000     12.000000      73.000000
# 75%      4655.000000    144.000000     587.000000
# max    299691.000000  27682.000000  132929.000000

# %% [markdown]
# ***
# ### Q1. Show the number of Confirmed, Deaths, and Recovered cases in each Region

# %%
df.groupby(['Region'])[['Confirmed', 'Deaths', 'Recovered']].sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %% [markdown]
# ***
# ### Q2. Remove all the records where Confirmed Cases are less than 10

# %%
df.drop(df[df['Confirmed'] < 10].index, axis = 0, inplace = True)

# %%
df.shape
# Out:
# (304, 6)

# %%
df[df['Confirmed'] < 10]
# Out:
# Empty DataFrame
# Columns: [Date, State, Region, Confirmed, Deaths, Recovered]
# Index: []

# %% [markdown]
# ***
# ### Q3. In which region, the maximum number of Confirmed Cases were recorded ?

# %%
df[df['Confirmed'] == df['Confirmed'].max()]
# Out:
#           Date     State Region  Confirmed  Deaths  Recovered
# 265  4/29/2020  New York     US     299691   23477          0

# %% [markdown]
# ***
# ### Q4. In which region, the minimum number of Deaths Cases were recorded ?

# %%
df[df['Deaths'] == df['Deaths'].min()]
# Out:
#           Date                         State  \
# 29   4/29/2020                           NaN
# 31   4/29/2020                           NaN
# 45   4/29/2020                           NaN
# 51   4/29/2020                           NaN
# 55   4/29/2020                           NaN
# 64   4/29/2020                           NaN
# 70   4/29/2020                           NaN
# 90   4/29/2020                           NaN
# 99   4/29/2020                           NaN
# 110  4/29/2020                           NaN
# 113  4/29/2020                           NaN
# 114  4/29/2020                           NaN
# 115  4/29/2020                           NaN
# 135  4/29/2020                           NaN
# 136  4/29/2020                           NaN
# 137  4/29/2020                           NaN
# 138  4/29/2020                           NaN
# 144  4/29/2020                           NaN
# 152  4/29/2020                           NaN
# 163  4/29/2020                           NaN
# ...

# %% [markdown]
# ***
# ### Q5. How many Confirmed, Deaths & Recovered cases were reported from India till 29 April 2020 ?

# %%
df[df['Region'] == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# ***
# ### Q6A. Sort the entire data set w.r.t. number of Confirmed cases in ascending order

# %%
df.sort_values(by = ['Confirmed'], ascending = True)
# Out:
#           Date      State    Region  Confirmed  Deaths  Recovered
# 156  4/29/2020        NaN  Suriname         10       1          8
# 70   4/29/2020        NaN  Holy See         10       0          2
# 59   4/29/2020        NaN    Gambia         10       1          8
# 318  4/29/2020      Yukon    Canada         11       0          0
# 217  4/29/2020  Greenland   Denmark         11       0         11
# ..         ...        ...       ...        ...     ...        ...
# 57   4/29/2020        NaN    France     165093   24087      48228
# 168  4/29/2020        NaN        UK     165221   26097          0
# 80   4/29/2020        NaN     Italy     203591   27682      71252
# 153  4/29/2020        NaN     Spain     236899   24275     132929
# 265  4/29/2020   New York        US     299691   23477          0
#
# [304 rows x 6 columns]

# %% [markdown]
# ***
# ### Q6B. Sort the entire data set w.r.t. number of Recovered cases in descending order

# %%
df.sort_values(by = ['Recovered'], ascending = False)
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020       NaN           Spain     236899   24275     132929
# 61   4/29/2020       NaN         Germany     161539    6467     120400
# 76   4/29/2020       NaN            Iran      93657    5957      73791
# 80   4/29/2020       NaN           Italy     203591   27682      71252
# 229  4/29/2020     Hubei  Mainland China      68128    4512      63616
# ..         ...       ...             ...        ...     ...        ...
# 258  4/29/2020    Nevada              US       4934     230          0
# 257  4/29/2020  Nebraska              US       3851      56          0
# 255  4/29/2020   Montana              US        451      16          0
# 254  4/29/2020  Missouri              US       7660     338          0
# 274  4/29/2020      Ohio              US      17303     937          0
#
# [304 rows x 6 columns]
